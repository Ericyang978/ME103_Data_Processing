# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import glob
import os
import csv
from scipy.stats import f_oneway
from scipy.stats import shapiro, levene, probplot
import math
import matplotlib.pyplot as plt
from statsmodels.stats.multicomp import pairwise_tukeyhsd


def load_tensile_csv(csv_path):
    """
    Loads tensile raw data CSVs that may contain:
      - metadata header lines
      - mixed delimiters
      - inconsistent column counts
    Returns a cleaned DataFrame with numeric columns only.
    """

    # First: Detect delimiter
    with open(csv_path, "r") as f:
        sample = f.read(2048)

    try:
        sniffer = csv.Sniffer()
        dialect = sniffer.sniff(sample, delimiters=[',',';','\t',' '])
        delimiter = dialect.delimiter
    except:
        delimiter = ','  # fallback

    # Second: Read the file while skipping bad rows
    df = pd.read_csv(
        csv_path,
        sep=delimiter,
        engine="python",
        comment='#',
        skiprows=5,
        #on_bad_lines='skip',    # <-- prevents crash
        skip_blank_lines=True
    )

    # Third: Drop EMPTY or non-numeric columns
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        except:
            df[col] = pd.NA

    df = df.dropna(axis=1, how='all')  # remove columns with no data
    df = df.dropna(axis=0, how='any')  # remove unfinished rows

    print(df)
    return df

def compute_youngs_modulus(
    csv_path,
    gauge_length,
    cross_section_area,
    load_col='Load',
    disp_col='Extension',
    elastic_strain_max=0.005
):
    """
    Computes Young's modulus from tensile test data.

    Parameters
    ----------
    csv_path : str
        Path to CSV file containing load/displacement data.
    gauge_length : float
        Original specimen length (m).
    cross_section_area : float
        Cross-sectional area (m^2).
    load_col : str
        Column name for load/force.
    disp_col : str
        Column name for displacement/extension.
    elastic_strain_max : float
        Maximum strain to use for the linear elastic fit (default = 0.5%).

    Returns
    -------
    E : float
        Estimated Young’s modulus (Pa).
    stress : ndarray
    strain : ndarray
        Arrays of engineering stress and strain.
    """

    # Load file
    df = load_tensile_csv(csv_path)

    # Extract data
    force = df[load_col].values
    disp  = df[disp_col].values

    # Engineering strain
    strain = disp / gauge_length

    # Engineering stress
    stress = force / cross_section_area

    # Select elastic region
    mask = strain <= elastic_strain_max
    strain_elastic = strain[mask].reshape(-1, 1)
    stress_elastic = stress[mask]

    # Linear regression (slope = E)
    model = LinearRegression().fit(strain_elastic, stress_elastic)
    E = model.coef_[0]

    return E, stress, strain

# %%
def ultimate_tensile_strength(stress):
    """
    Maximum stress achieved in the test.
    """
    return np.max(stress)

def offset_yield_strength(E, strain, stress, offset=0.02):
    """
    Computes the offset yield strength (default 2%).
    Uses interpolation to find intersection of stress-strain curve with
    offset line of slope equal to the elastic modulus.
    """
    offset_line = E*(strain - offset)

    # difference between actual curve and offset line
    diff = stress - offset_line
    
    # find zero crossing
    idx = np.where(np.diff(np.sign(diff)))[0]
    if len(idx) == 0:
        return None  # No yield point found
    
    i = idx[0]
    # linear interpolation for better accuracy
    x1, x2 = strain[i], strain[i+1]
    y1, y2 = diff[i], diff[i+1]
    
    strain_yield = x1 - y1*(x2 - x1)/(y2 - y1)
    stress_yield = np.interp(strain_yield, strain, stress)
    
    return stress_yield

def total_energy(strain, stress):
    """
    Integrates the stress-strain curve using the trapezoidal rule.
    Units depend on stress/strain units (e.g., MPa -> MJ/m^3).
    """
    return np.trapz(stress, strain)

def strain_at_fracture(strain):
    """
    Maximum strain recorded before failure.
    """
    return np.max(strain)

# %%
def analyze_tensile_folder(folder_path, gauge_length, cross_section_area):
    """
    Processes all CSV tensile data files in a folder and returns a summary table.
    """

    results = []

    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
    # print(csv_files)

    for csv_path in csv_files:
        try:
            # --- Stress & strain + Young's modulus ---
            E, stress, strain = compute_youngs_modulus(
                csv_path,
                gauge_length,
                cross_section_area
            )
            # print("fail 1")

            # --- Individual metrics ---
            uts = ultimate_tensile_strength(stress)
            # print("fail1.5")
            #ys  = offset_yield_strength(strain, stress, E)
            # print("fail1.5")
            energy = total_energy(strain, stress)
            # print("fail1.5")

            eps_f = strain_at_fracture(strain)
            # print("fail 2")
            results.append({
                "Filename": os.path.basename(csv_path),
                "Youngs_Modulus_Pa": E,
                "UTS_Pa": uts,
            #    "YieldStrength_2pct_Pa": ys,
                "TotalEnergy_Jperm3": energy,
                "StrainAtFracture": eps_f
            })

            # print(results, uts, energy, eps_f)

        except Exception as e:
            print(f"Error processing {csv_path}: {e}")

    return pd.DataFrame(results)

# %%
reference_tests = analyze_tensile_folder(
     "./Reference Tests/Reference_T1",
    1, 1
)

print(reference_tests)
# Out:
#        Time  Extension         Load
# 1     0.000   -0.04256      1.60519
# 2     0.100   -0.03807      1.36151
# 3     0.200   -0.02903     12.88276
# 4     0.300   -0.01960    149.19690
# 5     0.400   -0.01041    256.47833
# ..      ...        ...          ...
# 717  71.062    5.87952  11136.10156
# 718  71.064    5.87972  10348.32031
# 719  71.066    5.87992   9540.51465
# 720  71.068    5.88010   8732.13672
# 721  71.070    5.88030   7930.69141
#
# [721 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000      2.46954
# 2     0.100    0.00403      4.91734
# 3     0.200    0.01346     88.88831
# 4     0.300    0.02311    184.77623
# 5     0.400    0.03238    305.11151
# ..      ...        ...          ...
# 739  73.342    6.11218  10917.00684
# 740  73.344    6.11238  10172.36230
# 741  73.346    6.11258   9401.66895
# 742  73.348    6.11278   8625.38672
# 743  73.350    6.11298   7852.75635
#
# [743 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000   -0.08265     13.19987
# 2     0.100   -0.07814     12.30506
# 3     0.200   -0.06919     23.02709
# 4     0.300   -0.05967    123.57788
# 5     0.400   -0.05042    156.69598
# ..      ...        ...          ...
# 785  77.832    6.40360  11088.66504
# 786  77.834    6.40380  10325.13574
# 787  77.836    6.40400   9537.67578
# 788  77.838    6.40420   8744.85938
# 789  77.840    6.40438   7955.77637
#
# [789 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000   -0.05949     15.59371
# 2     0.100   -0.05289     16.28950
# 3     0.200   -0.04374     62.40662
# 4     0.300   -0.03424    181.42400
# 5     0.400   -0.02525    281.70602
# ..      ...        ...          ...
# 716  71.028    5.86165  10659.53125
# 717  71.030    5.86186   9908.54297
# 718  71.032    5.86206   9138.58398
# 719  71.034    5.86226   8366.86523
# 720  71.036    5.86246   7601.00537
#
# [720 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000   -0.04558      7.74583
# 2     0.100   -0.04057      7.67766
# 3     0.200   -0.03162     50.61907
# 4     0.300   -0.02230    185.39668
# 5     0.400   -0.01328    290.60876
# ..      ...        ...          ...
# 735  72.834    6.02413  10723.10547
# 736  72.836    6.02433   9966.34375
# 737  72.838    6.02454   9189.00391
# 738  72.840    6.02474   8411.32812
# 739  72.842    6.02491   7641.13721
#
# [739 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000     -0.17208
# 2     0.100    0.00436     -0.07179
# 3     0.200    0.01353      7.62889
# 4     0.300    0.02291    110.97145
# 5     0.400    0.03215    216.40686
# ..      ...        ...          ...
# 727  72.070    6.00609  11228.21875
# 728  72.072    6.00629  10464.26074
# 729  72.074    6.00649   9673.38574
# 730  72.076    6.00670   8871.79590
# 731  72.078    6.00690   8071.98730
#
# [731 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000   -0.04934      3.25848
# 2     0.100   -0.04508      3.08219
# 3     0.200   -0.03596      9.32547
# 4     0.300   -0.02656    100.22377
# 5     0.400   -0.01726    188.15869
# ..      ...        ...          ...
# 742  73.564    6.08126  11027.12695
# 743  73.566    6.08148  10273.13281
# 744  73.568    6.08169   9494.45020
# 745  73.570    6.08189   8708.69336
# 746  73.572    6.08209   7925.54639
#
# [746 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000      3.87223
# 2     0.100    0.00449      3.66772
# 3     0.200    0.01363     64.63068
# 4     0.300    0.02306    156.63063
# 5     0.400    0.03235    267.87369
# ..      ...        ...          ...
# 718  71.290    5.94108  11372.75879
# 719  71.292    5.94126  10641.34961
# 720  71.294    5.94146   9872.76270
# 721  71.296    5.94166   9089.49121
# 722  71.298    5.94186   8304.41699
#
# [722 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000      7.53494
# 2     0.100    0.00456      7.72691
# 3     0.200    0.01371     29.62387
# 4     0.300    0.02301    122.58210
# 5     0.400    0.03210    211.75502
# ..      ...        ...          ...
# 761  75.428    6.28584  10707.66406
# 762  75.430    6.28605   9944.93262
# 763  75.432    6.28627   9164.92188
# 764  75.434    6.28647   8384.79590
# 765  75.436    6.28667   7611.41309
#
# [765 rows x 3 columns]
#                   Filename  Youngs_Modulus_Pa       UTS_Pa  \
# 0   Specimen_RawData_6.csv        9173.990399  23291.40625
# 1   Specimen_RawData_7.csv         607.394541  23301.10352
# 2   Specimen_RawData_5.csv        3277.249196  23294.16016
# 3   Specimen_RawData_4.csv        9474.620760  23284.55078
# 4   Specimen_RawData_3.csv        9928.504189  23308.07812
# 5   Specimen_RawData_2.csv          23.002294  23337.07031
# 6   Specimen_RawData_9.csv        7695.411400  23310.40430
# 7   Specimen_RawData_8.csv         -45.547884  23254.04297
# 8  Specimen_RawData_10.csv          42.098684  23272.22070
#
#    TotalEnergy_Jperm3  StrainAtFracture
# 0        85336.213476           5.88030
# 1        88394.160517           6.11298
# 2        84685.289659           6.40438
# 3        81674.351496           5.86246
# 4        85997.823417           6.02491
# 5        86828.781308           6.00690
# 6        85331.333946           6.08209
# 7        85219.281905           5.94186
# 8        88477.887713           6.28667
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)

# %%
#ANOVA TEST
def run_anova_on_metric(results_dict, metric_col):
    """
    results_dict: dict[name -> DataFrame from analyze_tensile_folder]
    metric_col: string name of the column to test, e.g. "UTS_Pa"
    """
    group_values = []
    group_labels = []

    for condition_name, df in results_dict.items():
        # pull that column, drop NaN
        vals = df[metric_col].dropna().values

        # we need at least 2 samples for ANOVA to make sense
        if len(vals) >= 2:
            group_values.append(vals)
            group_labels.append(condition_name)
        else:
            print(f"Skipping {condition_name} for {metric_col} (only {len(vals)} sample(s))")

    if len(group_values) < 2:
        raise ValueError(f"Need at least 2 groups with data for ANOVA on {metric_col}")

    F, p = f_oneway(*group_values)

    print(f"\nANOVA for {metric_col}")
    print("Groups:", group_labels)
    print(f"F-statistic = {F:.4f}, p-value = {p:.4e}")

    return F, p, group_labels

# %%
#Shapiro test
def run_shapiro_per_group(results_by_condition, metric_col):
    """
    Run Shapiro–Wilk test for normality in each group (condition) for one metric.
    """
    print(f"\n=== Shapiro–Wilk normality test for {metric_col} ===")
    shapiro_results = []

    for condition_name, df in results_by_condition.items():
        vals = df[metric_col].dropna().values

        # Shapiro needs at least 3 points to be meaningful
        if len(vals) < 3:
            print(f"{condition_name}: n={len(vals)} (skipping, too few samples)")
            continue

        stat, p = shapiro(vals)
        shapiro_results.append({
            "Condition": condition_name,
            "n": len(vals),
            "W_stat": stat,
            "p_value": p
        })

        interpretation = "✅ approx. normal (fail to reject H0)" if p > 0.05 else "⚠️ non-normal (reject H0)"
        print(f"{condition_name}: n={len(vals)}, W={stat:.4f}, p={p:.4f} → {interpretation}")

    return pd.DataFrame(shapiro_results)

# %%
#Q-Q plots

def qq_plots_per_group(results_by_condition, metric_col):
    """
    Generate Q–Q plots for each group (condition) for one metric.
    """
    n_groups = len(results_by_condition)
    ncols = 3  # adjust if you want a different layout
    nrows = math.ceil(n_groups / ncols)

    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 4 * nrows))
    axes = np.array(axes).reshape(-1)  # flatten in case of 2D

    fig.suptitle(f"Q–Q plots for {metric_col}", fontsize=16)

    for ax, (condition_name, df) in zip(axes, results_by_condition.items()):
        vals = df[metric_col].dropna().values

        if len(vals) < 3:
            ax.set_title(f"{condition_name}\n(n={len(vals)}, skipped)")
            ax.axis("off")
            continue

        probplot(vals, dist="norm", plot=ax)
        ax.set_title(f"{condition_name} (n={len(vals)})")

    # Hide any extra axes if number of groups < nrows*ncols
    for j in range(len(results_by_condition), len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.show()

# %%
#LEVENES test
def run_levene_across_groups(results_by_condition, metric_col, center='median'):
    """
    Run Levene’s test for homogeneity of variances across groups for one metric.
    center: 'median' (more robust) or 'mean'
    """
    group_values = []
    group_labels = []

    for condition_name, df in results_by_condition.items():
        vals = df[metric_col].dropna().values
        if len(vals) < 2:
            print(f"{condition_name}: n={len(vals)} (skipping in Levene, too few samples)")
            continue
        group_values.append(vals)
        group_labels.append(condition_name)

    if len(group_values) < 2:
        raise ValueError(f"Need at least 2 groups with data for Levene’s test on {metric_col}")

    stat, p = levene(*group_values, center=center)

    interpretation = "✅ variances approx. equal (fail to reject H0)" if p > 0.05 else "⚠️ variances differ (reject H0)"

    print(f"\n=== Levene’s test for {metric_col} (center={center}) ===")
    print("Groups:", group_labels)
    print(f"Levene stat = {stat:.4f}, p = {p:.4f} → {interpretation}")

    return stat, p, group_labels

# %%
#Tukey HSD
def run_tukey_for_metric(results_by_condition, metric_col, alpha=0.05):
    """
    results_by_condition: dict[condition_name -> DataFrame from analyze_tensile_folder]
    metric_col: e.g. "UTS_Pa", "TotalEnergy_Jperm3", "StrainAtFracture"
    """
    all_values = []
    all_groups = []

    for condition_name, df in results_by_condition.items():
        vals = df[metric_col].dropna().values
        if len(vals) == 0:
            continue

        all_values.extend(vals)
        all_groups.extend([condition_name] * len(vals))

    all_values = np.array(all_values)
    all_groups = np.array(all_groups)

    tukey = pairwise_tukeyhsd(
        endog=all_values,   # the data
        groups=all_groups,  # group labels (folder names)
        alpha=alpha
    )

    print(f"\n=== Tukey HSD for {metric_col} (alpha = {alpha}) ===")
    print(tukey.summary())   # nice text table

    # Convert to DataFrame for easier viewing / export
    data = tukey._results_table.data
    header, rows = data[0], data[1:]
    tukey_df = pd.DataFrame(rows, columns=header)

    return tukey, tukey_df

# %%
#Goal 1

#get relevant folers
folder_names = ["Gyroid_8", "Gyroid_6", "Gyroid_4", "Solid_8", "Solid_6", "Solid_4", "Triangular_8", "Triangular_6", "Triangular_4"]
folder_addendum = ".is_tens_RawData"
parent_dir = "3DPrint"
folder_names_final = [os.path.join(parent_dir, name + folder_addendum) for name in folder_names]

#define lengths and section areas
L = 1 #in
A = 0.125*0.25 #in^2

#getting all the references
results_by_condition = {}

for i, folder_name in enumerate(folder_names_final):

    reference_tests = analyze_tensile_folder(
        folder_name,
        L, A
    )

    results_by_condition[folder_name] = reference_tests

#define metrics
metrics = [
    "UTS_Pa",              # ultimate tensile strength
    "TotalEnergy_Jperm3",  # energy absorbed
    "StrainAtFracture"     # elongation at break
]

#ANOVA
anova_results = []

for metric in metrics:
    F, p, groups = run_anova_on_metric(results_by_condition, metric)
    anova_results.append({
        "Metric": metric,
        "F_stat": F,
        "p_value": p
    })

print(anova_results)

#Shaprio
for metric in metrics:
    shapiro_df = run_shapiro_per_group(results_by_condition, metric)
    display(shapiro_df)

#levene's
for metric in metrics:
    run_levene_across_groups(results_by_condition, metric, center='median')

#Q-Q PLOT
# for metric in metrics:
#     qq_plots_per_group(results_by_condition, metric)

#Tukey
tukey_tables = {}

for metric in metrics:
    tukey_result, tukey_df = run_tukey_for_metric(results_by_condition, metric)
    tukey_tables[metric] = tukey_df
    display(tukey_df)
# Out:
#        Time  Extension         Load
# 1     0.000    0.00030     -2.64829
# 2     0.100    0.00764     43.94266
# 3     0.200    0.01751    104.44289
# 4     0.300    0.02691    132.00453
# 5     0.400    0.03581    182.97757
# ..      ...        ...          ...
# 384  37.884    3.16041  14899.19434
# 385  37.886    3.16064  13925.96191
# 386  37.888    3.16084  12905.07715
# 387  37.890    3.16104  11863.46484
# 388  37.892    3.16127  10824.25000
#
# [388 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000      0.93332
# 2     0.100    0.00403      2.96457
# 3     0.200    0.01341      7.14769
# 4     0.300    0.02283     80.13934
# 5     0.400    0.03210    169.43657
# ..      ...        ...          ...
# 364  35.826    2.98581  14494.72461
# 365  35.828    2.98601  13531.48340
# 366  35.830    2.98621  12524.41406
# 367  35.832    2.98641  11500.87891
# 368  35.834    2.98662  10481.74609
#
# [368 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000      8
rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000     -4.23895
# 2     0.100    0.00454     15.90273
# 3     0.200    0.01436    133.06631
# 4     0.300    0.02376    231.95105
# 5     0.400    0.03263    320.91379
# ..      ...        ...          ...
# 296  29.014    2.41809  11100.02148
# 297  29.016    2.41829  10339.58594
# 298  29.018    2.41849   9550.21387
# 299  29.020    2.41869   8752.77051
# 300  29.022    2.41890   7962.61865
#
# [300 rows x 3 columns]
#        Time  Extension         Load
# 1     0.000    0.00000     -6.40358
# 2     0.100    0.00438     -8.34239
# 3     0.200    0.01383     44.88046
# 4     0.300    0.02333    161.51292
# 5     0.400    0.03241    266.42874
# ..      ...        ...          ...
# 288  28.246    2.35404  11117.52539
# 289  28.248    2.35424  10367.75879
# 290  28.250    2.35444   9586.39648
# 291  28.252    2.35464   8794.35059
# 292  28.254    2.35484   8008.23877
#
# [292 rows x 3 columns]
#
# ANOVA for UTS_Pa
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# F-statistic = 7997.1461, p-value = 1.6987e-43
#
# ANOVA for TotalEnergy_Jperm3
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# F-statistic = 569.2061, p-value = 4.8390e-28
#
# ANOVA for StrainAtFracture
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# F-statistic = 119.2664, p-value = 4.9240e-19
# [{'Metric': 'UTS_Pa', 'F_stat': np.float64(7997.146107235382), 'p_value': np.float64(1.698712396743185e-43)}, {'Metric': 'TotalEnergy_Jperm3', 'F_stat': np.float64(569.2060652807993), 'p_value': np.float64(4.839044213359062e-28)}, {'Metric': 'StrainAtFracture', 'F_stat': np.float64(119.26635677077299), 'p_value': np.float64(4.923989864377733e-19)}]
#
# === Shapiro–Wilk normality test for UTS_Pa ===
# 3DPrint/Gyroid_8.is_tens_RawData: n=4, W=0.7786, p=0.0690 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_6.is_tens_RawData: n=4, W=0.7924, p=0.0892 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_4.is_tens_RawData: n=4, W=0.9506, p=0.7197 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_8.is_tens_RawData: n=4, W=0.8275, p=0.1613 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_6.is_tens_RawData: n=4, W=0.9517, p=0.7265 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_4.is_tens_RawData: n=4, W=0.8250, p=0.1551 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_8.is_tens_RawData: n=4, W=0.9113, p=0.4895 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_6.is_tens_RawData: n=4, W=0.9994, p=0.9984 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_4.is_tens_RawData: n=4, W=0.9343, p=0.6201 → ✅ approx. normal (fail to reject H0)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
# /var/folders/kw/6h6rqb2d1y90cxs7kdn3lf3r0000gn/T/ipykernel_82947/1993934651.py:38: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   return np.trapz(stress, strain)
#                               Condition  n    W_stat   p_value
# 0      3DPrint/Gyroid_8.is_tens_RawData  4  0.778583  0.069032
# 1      3DPrint/Gyroid_6.is_tens_RawData  4  0.792358  0.089206
# 2      3DPrint/Gyroid_4.is_tens_RawData  4  0.950580  0.719740
# 3       3DPrint/Solid_8.is_tens_RawData  4  0.827487  0.161342
# 4       3DPrint/Solid_6.is_tens_RawData  4  0.951657  0.726480
# 5       3DPrint/Solid_4.is_tens_RawData  4  0.824975  0.155074
# 6  3DPrint/Triangular_8.is_tens_RawData  4  0.911332  0.489485
# 7  3DPrint/Triangular_6.is_tens_RawData  4  0.999425  0.998424
# 8  3DPrint/Triangular_4.is_tens_RawData  4  0.934332  0.620089
# === Shapiro–Wilk normality test for TotalEnergy_Jperm3 ===
# 3DPrint/Gyroid_8.is_tens_RawData: n=4, W=0.9324, p=0.6087 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_6.is_tens_RawData: n=4, W=0.8827, p=0.3502 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_4.is_tens_RawData: n=4, W=0.9702, p=0.8427 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_8.is_tens_RawData: n=4, W=0.9245, p=0.5625 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_6.is_tens_RawData: n=4, W=0.9129, p=0.4978 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_4.is_tens_RawData: n=4, W=0.8315, p=0.1718 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_8.is_tens_RawData: n=4, W=0.8570, p=0.2497 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_6.is_tens_RawData: n=4, W=0.9842, p=0.9261 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_4.is_tens_RawData: n=4, W=0.9535, p=0.7378 → ✅ approx. normal (fail to reject H0)
#                               Condition  n    W_stat   p_value
# 0      3DPrint/Gyroid_8.is_tens_RawData  4  0.932413  0.608655
# 1      3DPrint/Gyroid_6.is_tens_RawData  4  0.882681  0.350212
# 2      3DPrint/Gyroid_4.is_tens_RawData  4  0.970195  0.842693
# 3       3DPrint/Solid_8.is_tens_RawData  4  0.924512  0.562530
# 4       3DPrint/Solid_6.is_tens_RawData  4  0.912882  0.497804
# 5       3DPrint/Solid_4.is_tens_RawData  4  0.831538  0.171849
# 6  3DPrint/Triangular_8.is_tens_RawData  4  0.857010  0.249679
# 7  3DPrint/Triangular_6.is_tens_RawData  4  0.984180  0.926068
# 8  3DPrint/Triangular_4.is_tens_RawData  4  0.953459  0.737779
# === Shapiro–Wilk normality test for StrainAtFracture ===
# 3DPrint/Gyroid_8.is_tens_RawData: n=4, W=0.9245, p=0.5622 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_6.is_tens_RawData: n=4, W=0.8752, p=0.3187 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Gyroid_4.is_tens_RawData: n=4, W=0.7401, p=0.0311 → ⚠️ non-normal (reject H0)
# 3DPrint/Solid_8.is_tens_RawData: n=4, W=0.9565, p=0.7569 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_6.is_tens_RawData: n=4, W=0.8035, p=0.1086 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Solid_4.is_tens_RawData: n=4, W=0.9599, p=0.7780 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_8.is_tens_RawData: n=4, W=0.9119, p=0.4926 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_6.is_tens_RawData: n=4, W=0.9760, p=0.8782 → ✅ approx. normal (fail to reject H0)
# 3DPrint/Triangular_4.is_tens_RawData: n=4, W=0.9068, p=0.4656 → ✅ approx. normal (fail to reject H0)
#                               Condition  n    W_stat   p_value
# 0      3DPrint/Gyroid_8.is_tens_RawData  4  0.924455  0.562206
# 1      3DPrint/Gyroid_6.is_tens_RawData  4  0.875246  0.318728
# 2      3DPrint/Gyroid_4.is_tens_RawData  4  0.740092  0.031060
# 3       3DPrint/Solid_8.is_tens_RawData  4  0.956510  0.756948
# 4       3DPrint/Solid_6.is_tens_RawData  4  0.803474  0.108597
# 5       3DPrint/Solid_4.is_tens_RawData  4  0.959858  0.778016
# 6  3DPrint/Triangular_8.is_tens_RawData  4  0.911914  0.492600
# 7  3DPrint/Triangular_6.is_tens_RawData  4  0.975998  0.878191
# 8  3DPrint/Triangular_4.is_tens_RawData  4  0.906788  0.465552
# === Levene’s test for UTS_Pa (center=median) ===
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# Levene stat = 1.1720, p = 0.3512 → ✅ variances approx. equal (fail to reject H0)
#
# === Levene’s test for TotalEnergy_Jperm3 (center=median) ===
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# Levene stat = 1.7861, p = 0.1240 → ✅ variances approx. equal (fail to reject H0)
#
# === Levene’s test for StrainAtFracture (center=median) ===
# Groups: ['3DPrint/Gyroid_8.is_tens_RawData', '3DPrint/Gyroid_6.is_tens_RawData', '3DPrint/Gyroid_4.is_tens_RawData', '3DPrint/Solid_8.is_tens_RawData', '3DPrint/Solid_6.is_tens_RawData', '3DPrint/Solid_4.is_tens_RawData', '3DPrint/Triangular_8.is_tens_RawData', '3DPrint/Triangular_6.is_tens_RawData', '3DPrint/Triangular_4.is_tens_RawData']
# Levene stat = 1.0422, p = 0.4303 → ✅ variances approx. equal (fail to reject H0)
#
# === Tukey HSD for UTS_Pa (alpha = 0.05) ===
#                                      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================================================================
#                group1                               group2                  meandiff   p-adj     lower        upper     reject
# ------------------------------------------------------------------------------------------------------------------------------
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_6.is_tens_RawData   85602.4843    0.0   77368.6342   93836.3344   True
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData  132935.9062    0.0  124702.0561  141169.7564   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData  355387.3749    0.0  347153.5248   363621.225   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData    363885.25    0.0  355651.3999  372119.1001   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  364401.8125    0.0  356167.9624  372635.6626   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData   -7632.5234 0.0852  -15866.3736     601.3267  False
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData   59307.7108    0.0   51073.8607   67541.5609   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  143003.9218    0.0  134770.0716  151237.7719   True
#     3DPrint/Gyroid_6.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData   47333.4219    0.0   39099.5718    55567.272   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData  269784.8906    0.0  261551.0404  278018.7407   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  278282.7657    0.0  270048.9156  286516.6158   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  278799.3282    0.0   270565.478  287033.1783   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -93235.0078    0.0 -101468.8579  -85001.1576   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -26294.7735    0.0  -34528.6236  -18060.9234   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   57401.4374    0.0   49167.5873   65635.2876   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData  222451.4686    0.0  214217.6185  230685.3188   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  230949.3438    0.0  222715.4936  239183.1939   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  231465.9062    0.0  223232.0561  239699.7564   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData -140568.4297    0.0 -148802.2798 -132334.5796   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -73628.1954    0.0  -81862.0456  -65394.3453   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   10068.0155 0.0084    1834.1654   18301.8656   True
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData    8497.8751 0.0392      264.025   16731.7252   True
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData    9014.4376  0.024     780.5875   17248.2877   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData -363019.8983    0.0 -371253.7484 -354786.0482   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData -296079.6641    0.0 -304313.5142  -287845.814   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData -212383.4531    0.0 -220617.3032  -204149.603   True
#      3DPrint/Solid_6.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData     516.5625    1.0   -7717.2876    8750.4126  False
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData -371517.7734    0.0 -379751.6236 -363283.9233   True
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData -304577.5392    0.0 -312811.3893 -296343.6891   True
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData -220881.3282    0.0 -229115.1784 -212647.4781   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData -372034.3359    0.0  -380268.186 -363800.4858   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData -305094.1017    0.0 -313327.9518 -296860.2516   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData -221397.8907    0.0 -229631.7408 -213164.0406   True
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData   66940.2342    0.0   58706.3841   75174.0844   True
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  150636.4452    0.0  142402.5951  158870.2953   True
# 3DPrint/Triangular_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData    83696.211    0.0   75462.3608   91930.0611   True
# ------------------------------------------------------------------------------------------------------------------------------
#                                   group1  \
# 0       3DPrint/Gyroid_4.is_tens_RawData
# 1       3DPrint/Gyroid_4.is_tens_RawData
# 2       3DPrint/Gyroid_4.is_tens_RawData
# 3       3DPrint/Gyroid_4.is_tens_RawData
# 4       3DPrint/Gyroid_4.is_tens_RawData
# 5       3DPrint/Gyroid_4.is_tens_RawData
# 6       3DPrint/Gyroid_4.is_tens_RawData
# 7       3DPrint/Gyroid_4.is_tens_RawData
# 8       3DPrint/Gyroid_6.is_tens_RawData
# 9       3DPrint/Gyroid_6.is_tens_RawData
# 10      3DPrint/Gyroid_6.is_tens_RawData
# 11      3DPrint/Gyroid_6.is_tens_RawData
# 12      3DPrint/Gyroid_6.is_tens_RawData
# 13      3DPrint/Gyroid_6.is_tens_RawData
# 14      3DPrint/Gyroid_6.is_tens_RawData
# 15      3DPrint/Gyroid_8.is_tens_RawData
# 16      3DPrint/Gyroid_8.is_tens_RawData
# 17      3DPrint/Gyroid_8.is_tens_RawData
# 18      3DPrint/Gyroid_8.is_tens_RawData
# 19      3DPrint/Gyroid_8.is_tens_RawData
# 20      3DPrint/Gyroid_8.is_tens_RawData
# 21       3DPrint/Solid_4.is_tens_RawData
# 22       3DPrint/Solid_4.is_tens_RawData
# 23       3DPrint/Solid_4.is_tens_RawData
# 24       3DPrint/Solid_4.is_tens_RawData
# 25       3DPrint/Solid_4.is_tens_RawData
# 26       3DPrint/Solid_6.is_tens_RawData
# 27       3DPrint/Solid_6.is_tens_RawData
# 28       3DPrint/Solid_6.is_tens_RawData
# 29       3DPrint/Solid_6.is_tens_RawData
# 30       3DPrint/Solid_8.is_tens_RawData
# 31       3DPrint/Solid_8.is_tens_RawData
# 32       3DPrint/Solid_8.is_tens_RawData
# 33  3DPrint/Triangular_4.is_tens_RawData
# 34  3DPrint/Triangular_4.is_tens_RawData
# 35  3DPrint/Triangular_6.is_tens_RawData
#
#                                   group2     meandiff   p-adj        lower  \
# 0       3DPrint/Gyroid_6.is_tens_RawData   85602.4843  0.0000   77368.6342
# 1       3DPrint/Gyroid_8.is_tens_RawData  132935.9062  0.0000  124702.0561
# 2        3DPrint/Solid_4.is_tens_RawData  355387.3749  0.0000  347153.5248
# 3        3DPrint/Solid_6.is_tens_RawData  363885.2500  0.0000  355651.3999
# 4        3DPrint/Solid_8.is_tens_RawData  364401.8125  0.0000  356167.9624
# 5   3DPrint/Triangular_4.is_tens_RawData   -7632.5234  0.0852  -15866.3736
# 6   3DPrint/Triangular_6.is_tens_RawData   59307.7108  0.0000   51073.8607
# 7   3DPrint/Triangular_8.is_tens_RawData  143003.9218  0.0000  134770.0716
# 8       3DPrint/Gyroid_8.is_tens_RawData   47333.4219  0.0000   39099.5718
# 9        3DPrint/Solid_4.is_tens_RawData  269784.8906  0.0000  261551.0404
# 10       3DPrint/Solid_6.is_tens_RawData  278282.7657  0.0000  270048.9156
# 11       3DPrint/Solid_8.is_tens_RawData  278799.3282  0.0000  270565.4780
# 12  3DPrint/Triangular_4.is_tens_RawData  -93235.0078  0.0000 -101468.8579
# 13  3DPrint/Triangular_6.is_tens_RawData  -26294.7735  0.0000  -34528.6236
# 14  3DPrint/Triangular_8.is_tens_RawData   57401.4374  0.0000   49167.5873
# 15       3DPrint/Solid_4.is_tens_RawData  222451.4686  0.0000  214217.6185
# 16       3DPrint/Solid_6.is_tens_RawData  230949.3438  0.0000  222715.4936
# 17       3DPrint/Solid_8.is_tens_RawData  231465.9062  0.0000  223232.0561
# 18  3DPrint/Triangular_4.is_tens_RawData -140568.4297  0.0000 -148802.2798
# 19  3DPrint/Triangular_6.is_tens_RawData  -73628.1954  0.0000  -81862.0456
# 20  3DPrint/Triangular_8.is_tens_RawData   10068.0155  0.0084    1834.1654
# 21       3DPrint/Solid_6.is_tens_RawData    8497.8751  0.0392     264.0250
# 22       3DPrint/Solid_8.is_tens_RawData    9014.4376  0.0240     780.5875
# 23  3DPrint/Triangular_4.is_tens_RawData -363019.8983  0.0000 -371253.7484
# 24  3DPrint/Triangular_6.is_tens_RawData -296079.6641  0.0000 -304313.5142
# 25  3DPrint/Triangular_8.is_tens_RawData -212383.4531  0.0000 -220617.3032
# 26       3DPrint/Solid_8.is_tens_RawData     516.5625  1.0000   -7717.2876
# 27  3DPrint/Triangular_4.is_tens_RawData -371517.7734  0.0000 -379751.6236
# 28  3DPrint/Triangular_6.is_tens_RawData -304577.5392  0.0000 -312811.3893
# 29  3DPrint/Triangular_8.is_tens_RawData -220881.3282  0.0000 -229115.1784
# 30  3DPrint/Triangular_4.is_tens_RawData -372034.3359  0.0000 -380268.1860
# 31  3DPrint/Triangular_6.is_tens_RawData -305094.1017  0.0000 -313327.9518
# 32  3DPrint/Triangular_8.is_tens_RawData -221397.8907  0.0000 -229631.7408
# 33  3DPrint/Triangular_6.is_tens_RawData   66940.2342  0.0000   58706.3841
# 34  3DPrint/Triangular_8.is_tens_RawData  150636.4452  0.0000  142402.5951
# 35  3DPrint/Triangular_8.is_tens_RawData   83696.2110  0.0000   75462.3608
#
#           upper  reject
# 0    93836.3344    True
# 1   141169.7564    True
# 2   363621.2250    True
# 3   372119.1001    True
# 4   372635.6626    True
# 5      601.3267   False
# 6    67541.5609    True
# 7   151237.7719    True
# 8    55567.2720    True
# 9   278018.7407    True
# 10  286516.6158    True
# 11  287033.1783    True
# 12  -85001.1576    True
# 13  -18060.9234    True
# 14   65635.2876    True
# 15  230685.3188    True
# 16  239183.1939    True
# 17  239699.7564    True
# 18 -132334.5796    True
# 19  -65394.3453    True
# 20   18301.8656    True
# 21   16731.7252    True
# 22   17248.2877    True
# 23 -354786.0482    True
# 24 -287845.8140    True
# 25 -204149.6030    True
# 26    8750.4126   False
# 27 -363283.9233    True
# 28 -296343.6891    True
# 29 -212647.4781    True
# 30 -363800.4858    True
# 31 -296860.2516    True
# 32 -213164.0406    True
# 33   75174.0844    True
# 34  158870.2953    True
# 35   91930.0611    True
# === Tukey HSD for TotalEnergy_Jperm3 (alpha = 0.05) ===
#                                        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================================================================================
#                group1                               group2                   meandiff   p-adj      lower         upper     reject
# ---------------------------------------------------------------------------------------------------------------------------------
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_6.is_tens_RawData   303768.5553    0.0   153435.0842   454102.0264   True
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData   176213.5627 0.0128    25880.0916   326547.0338   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData   1490912.107    0.0  1340578.6359  1641245.5781   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  1566966.6219    0.0  1416633.1508   1717300.093   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  1569327.2656    0.0  1418993.7945  1719660.7368   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -207210.6637 0.0022  -357544.1349   -56877.1926   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData   -39813.5106 0.9916  -190146.9817   110519.9605  False
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   146448.1999 0.0606    -3885.2712    296781.671  False
#     3DPrint/Gyroid_6.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData  -127554.9926 0.1455  -277888.4637    22778.4785  False
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData  1187143.5517    0.0  1036810.0806  1337477.0228   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  1263198.0666    0.0  1112864.5955  1413531.5377   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  1265558.7103    0.0  1115225.2392  1415892.1814   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData   -510979.219    0.0  -661312.6902  -360645.7479   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -343582.0659    0.0   -493915.537  -193248.5948   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -157320.3554 0.0351  -307653.8266    -6986.8843   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData  1314698.5443    0.0  1164365.0732  1465032.0154   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  1390753.0592    0.0  1240419.5881  1541086.5303   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  1393113.7029    0.0  1242780.2318   1543447.174   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -383424.2264    0.0  -533757.6976  -233090.7553   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -216027.0733 0.0014  -366360.5444   -65693.6022   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   -29765.3628 0.9989   -180098.834   120568.1083  False
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData    76054.5149 0.7401   -74278.9562   226387.9861  False
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData    78415.1587  0.709   -71918.3125   228748.6298  False
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData -1698122.7707    0.0 -1848456.2418 -1547789.2996   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData -1530725.6176    0.0 -1681059.0887 -1380392.1465   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData -1344463.9071    0.0 -1494797.3782  -1194130.436   True
# ...
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData -1422879.0658    0.0 -1573212.5369 -1272545.5947   True
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData   167397.1531 0.0207     17063.682   317730.6242   True
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   353658.8636    0.0   203325.3925   503992.3347   True
# 3DPrint/Triangular_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   186261.7105 0.0074    35928.2394   336595.1816   True
# ---------------------------------------------------------------------------------------------------------------------------------
#                                   group1  \
# 0       3DPrint/Gyroid_4.is_tens_RawData
# 1       3DPrint/Gyroid_4.is_tens_RawData
# 2       3DPrint/Gyroid_4.is_tens_RawData
# 3       3DPrint/Gyroid_4.is_tens_RawData
# 4       3DPrint/Gyroid_4.is_tens_RawData
# 5       3DPrint/Gyroid_4.is_tens_RawData
# 6       3DPrint/Gyroid_4.is_tens_RawData
# 7       3DPrint/Gyroid_4.is_tens_RawData
# 8       3DPrint/Gyroid_6.is_tens_RawData
# 9       3DPrint/Gyroid_6.is_tens_RawData
# 10      3DPrint/Gyroid_6.is_tens_RawData
# 11      3DPrint/Gyroid_6.is_tens_RawData
# 12      3DPrint/Gyroid_6.is_tens_RawData
# 13      3DPrint/Gyroid_6.is_tens_RawData
# 14      3DPrint/Gyroid_6.is_tens_RawData
# 15      3DPrint/Gyroid_8.is_tens_RawData
# 16      3DPrint/Gyroid_8.is_tens_RawData
# 17      3DPrint/Gyroid_8.is_tens_RawData
# 18      3DPrint/Gyroid_8.is_tens_RawData
# 19      3DPrint/Gyroid_8.is_tens_RawData
# 20      3DPrint/Gyroid_8.is_tens_RawData
# 21       3DPrint/Solid_4.is_tens_RawData
# 22       3DPrint/Solid_4.is_tens_RawData
# 23       3DPrint/Solid_4.is_tens_RawData
# 24       3DPrint/Solid_4.is_tens_RawData
# 25       3DPrint/Solid_4.is_tens_RawData
# 26       3DPrint/Solid_6.is_tens_RawData
# 27       3DPrint/Solid_6.is_tens_RawData
# 28       3DPrint/Solid_6.is_tens_RawData
# 29       3DPrint/Solid_6.is_tens_RawData
# 30       3DPrint/Solid_8.is_tens_RawData
# 31       3DPrint/Solid_8.is_tens_RawData
# 32       3DPrint/Solid_8.is_tens_RawData
# 33  3DPrint/Triangular_4.is_tens_RawData
# 34  3DPrint/Triangular_4.is_tens_RawData
# 35  3DPrint/Triangular_6.is_tens_RawData
#
#                                   group2      meandiff   p-adj         lower  \
# 0       3DPrint/Gyroid_6.is_tens_RawData  3.037686e+05  0.0000  1.534351e+05
# 1       3DPrint/Gyroid_8.is_tens_RawData  1.762136e+05  0.0128  2.588009e+04
# 2        3DPrint/Solid_4.is_tens_RawData  1.490912e+06  0.0000  1.340579e+06
# 3        3DPrint/Solid_6.is_tens_RawData  1.566967e+06  0.0000  1.416633e+06
# 4        3DPrint/Solid_8.is_tens_RawData  1.569327e+06  0.0000  1.418994e+06
# 5   3DPrint/Triangular_4.is_tens_RawData -2.072107e+05  0.0022 -3.575441e+05
# 6   3DPrint/Triangular_6.is_tens_RawData -3.981351e+04  0.9916 -1.901470e+05
# 7   3DPrint/Triangular_8.is_tens_RawData  1.464482e+05  0.0606 -3.885271e+03
# 8       3DPrint/Gyroid_8.is_tens_RawData -1.275550e+05  0.1455 -2.778885e+05
# 9        3DPrint/Solid_4.is_tens_RawData  1.187144e+06  0.0000  1.036810e+06
# 10       3DPrint/Solid_6.is_tens_RawData  1.263198e+06  0.0000  1.112865e+06
# 11       3DPrint/Solid_8.is_tens_RawData  1.265559e+06  0.0000  1.115225e+06
# 12  3DPrint/Triangular_4.is_tens_RawData -5.109792e+05  0.0000 -6.613127e+05
# 13  3DPrint/Triangular_6.is_tens_RawData -3.435821e+05  0.0000 -4.939155e+05
# 14  3DPrint/Triangular_8.is_tens_RawData -1.573204e+05  0.0351 -3.076538e+05
# 15       3DPrint/Solid_4.is_tens_RawData  1.314699e+06  0.0000  1.164365e+06
# 16       3DPrint/Solid_6.is_tens_RawData  1.390753e+06  0.0000  1.240420e+06
# 17       3DPrint/Solid_8.is_tens_RawData  1.393114e+06  0.0000  1.242780e+06
# 18  3DPrint/Triangular_4.is_tens_RawData -3.834242e+05  0.0000 -5.337577e+05
# 19  3DPrint/Triangular_6.is_tens_RawData -2.160271e+05  0.0014 -3.663605e+05
# 20  3DPrint/Triangular_8.is_tens_RawData -2.976536e+04  0.9989 -1.800988e+05
# 21       3DPrint/Solid_6.is_tens_RawData  7.605451e+04  0.7401 -7.427896e+04
# 22       3DPrint/Solid_8.is_tens_RawData  7.841516e+04  0.7090 -7.191831e+04
# 23  3DPrint/Triangular_4.is_tens_RawData -1.698123e+06  0.0000 -1.848456e+06
# 24  3DPrint/Triangular_6.is_tens_RawData -1.530726e+06  0.0000 -1.681059e+06
# 25  3DPrint/Triangular_8.is_tens_RawData -1.344464e+06  0.0000 -1.494797e+06
# 26       3DPrint/Solid_8.is_tens_RawData  2.360644e+03  1.0000 -1.479728e+05
# 27  3DPrint/Triangular_4.is_tens_RawData -1.774177e+06  0.0000 -1.924511e+06
# 28  3DPrint/Triangular_6.is_tens_RawData -1.606780e+06  0.0000 -1.757114e+06
# 29  3DPrint/Triangular_8.is_tens_RawData -1.420518e+06  0.0000 -1.570852e+06
# 30  3DPrint/Triangular_4.is_tens_RawData -1.776538e+06  0.0000 -1.926871e+06
# 31  3DPrint/Triangular_6.is_tens_RawData -1.609141e+06  0.0000 -1.759474e+06
# 32  3DPrint/Triangular_8.is_tens_RawData -1.422879e+06  0.0000 -1.573213e+06
# 33  3DPrint/Triangular_6.is_tens_RawData  1.673972e+05  0.0207  1.706368e+04
# 34  3DPrint/Triangular_8.is_tens_RawData  3.536589e+05  0.0000  2.033254e+05
# 35  3DPrint/Triangular_8.is_tens_RawData  1.862617e+05  0.0074  3.592824e+04
#
#            upper  reject
# 0   4.541020e+05    True
# 1   3.265470e+05    True
# 2   1.641246e+06    True
# 3   1.717300e+06    True
# 4   1.719661e+06    True
# 5  -5.687719e+04    True
# 6   1.105200e+05   False
# 7   2.967817e+05   False
# 8   2.277848e+04   False
# 9   1.337477e+06    True
# 10  1.413532e+06    True
# 11  1.415892e+06    True
# 12 -3.606457e+05    True
# 13 -1.932486e+05    True
# 14 -6.986884e+03    True
# 15  1.465032e+06    True
# 16  1.541087e+06    True
# 17  1.543447e+06    True
# 18 -2.330908e+05    True
# 19 -6.569360e+04    True
# 20  1.205681e+05   False
# 21  2.263880e+05   False
# 22  2.287486e+05   False
# 23 -1.547789e+06    True
# 24 -1.380392e+06    True
# 25 -1.194130e+06    True
# 26  1.526941e+05   False
# 27 -1.623844e+06    True
# 28 -1.456447e+06    True
# 29 -1.270185e+06    True
# 30 -1.626204e+06    True
# 31 -1.458807e+06    True
# 32 -1.272546e+06    True
# 33  3.177306e+05    True
# 34  5.039923e+05    True
# 35  3.365952e+05    True
# === Tukey HSD for StrainAtFracture (alpha = 0.05) ===
#                               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================================================================
#                group1                               group2                meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------------------------------------------
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_6.is_tens_RawData   0.4523 0.0102  0.0753  0.8294   True
#     3DPrint/Gyroid_4.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData    -0.02    1.0 -0.3971   0.357  False
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData   1.4803    0.0  1.1032  1.8573   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData   1.4349    0.0  1.0579   1.812   True
#     3DPrint/Gyroid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData   1.4698    0.0  1.0927  1.8468   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -0.7056    0.0 -1.0826 -0.3286   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -0.4218 0.0198 -0.7989 -0.0448   True
#     3DPrint/Gyroid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -0.2107 0.6321 -0.5877  0.1664  False
#     3DPrint/Gyroid_6.is_tens_RawData     3DPrint/Gyroid_8.is_tens_RawData  -0.4723 0.0066 -0.8494 -0.0953   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData   1.0279    0.0  0.6509   1.405   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData   0.9826    0.0  0.6056  1.3597   True
#     3DPrint/Gyroid_6.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData   1.0174    0.0  0.6404  1.3945   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -1.1579    0.0  -1.535 -0.7809   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -0.8741    0.0 -1.2512 -0.4971   True
#     3DPrint/Gyroid_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   -0.663 0.0001   -1.04 -0.2859   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_4.is_tens_RawData   1.5003    0.0  1.1232  1.8773   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData    1.455    0.0  1.0779   1.832   True
#     3DPrint/Gyroid_8.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData   1.4898    0.0  1.1128  1.8668   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -0.6856    0.0 -1.0626 -0.3085   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -0.4018 0.0302 -0.7788 -0.0248   True
#     3DPrint/Gyroid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -0.1906 0.7407 -0.5677  0.1864  False
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_6.is_tens_RawData  -0.0453    1.0 -0.4224  0.3317  False
#      3DPrint/Solid_4.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData  -0.0105    1.0 -0.3875  0.3666  False
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -2.1859    0.0 -2.5629 -1.8088   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -1.9021    0.0 -2.2791  -1.525   True
#      3DPrint/Solid_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -1.6909    0.0  -2.068 -1.3139   True
#      3DPrint/Solid_6.is_tens_RawData      3DPrint/Solid_8.is_tens_RawData   0.0348    1.0 -0.3422  0.4119  False
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -2.1405    0.0 -2.5176 -1.7635   True
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -1.8568    0.0 -2.2338 -1.4797   True
#      3DPrint/Solid_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -1.6456    0.0 -2.0226 -1.2685   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_4.is_tens_RawData  -2.1754    0.0 -2.5524 -1.7983   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData  -1.8916    0.0 -2.2686 -1.5145   True
#      3DPrint/Solid_8.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData  -1.6804    0.0 -2.0575 -1.3034   True
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_6.is_tens_RawData   0.2838  0.261 -0.0933  0.6608  False
# 3DPrint/Triangular_4.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   0.4949 0.0039  0.1179   0.872   True
# 3DPrint/Triangular_6.is_tens_RawData 3DPrint/Triangular_8.is_tens_RawData   0.2112 0.6293 -0.1659  0.5882  False
# ----------------------------------------------------------------------------------------------------------------
#                                   group1  \
# 0       3DPrint/Gyroid_4.is_tens_RawData
# 1       3DPrint/Gyroid_4.is_tens_RawData
# 2       3DPrint/Gyroid_4.is_tens_RawData
# 3       3DPrint/Gyroid_4.is_tens_RawData
# 4       3DPrint/Gyroid_4.is_tens_RawData
# 5       3DPrint/Gyroid_4.is_tens_RawData
# 6       3DPrint/Gyroid_4.is_tens_RawData
# 7       3DPrint/Gyroid_4.is_tens_RawData
# 8       3DPrint/Gyroid_6.is_tens_RawData
# 9       3DPrint/Gyroid_6.is_tens_RawData
# 10      3DPrint/Gyroid_6.is_tens_RawData
# 11      3DPrint/Gyroid_6.is_tens_RawData
# 12      3DPrint/Gyroid_6.is_tens_RawData
# 13      3DPrint/Gyroid_6.is_tens_RawData
# 14      3DPrint/Gyroid_6.is_tens_RawData
# 15      3DPrint/Gyroid_8.is_tens_RawData
# 16      3DPrint/Gyroid_8.is_tens_RawData
# 17      3DPrint/Gyroid_8.is_tens_RawData
# 18      3DPrint/Gyroid_8.is_tens_RawData
# 19      3DPrint/Gyroid_8.is_tens_RawData
# 20      3DPrint/Gyroid_8.is_tens_RawData
# 21       3DPrint/Solid_4.is_tens_RawData
# 22       3DPrint/Solid_4.is_tens_RawData
# 23       3DPrint/Solid_4.is_tens_RawData
# 24       3DPrint/Solid_4.is_tens_RawData
# 25       3DPrint/Solid_4.is_tens_RawData
# 26       3DPrint/Solid_6.is_tens_RawData
# 27       3DPrint/Solid_6.is_tens_RawData
# 28       3DPrint/Solid_6.is_tens_RawData
# 29       3DPrint/Solid_6.is_tens_RawData
# 30       3DPrint/Solid_8.is_tens_RawData
# 31       3DPrint/Solid_8.is_tens_RawData
# 32       3DPrint/Solid_8.is_tens_RawData
# 33  3DPrint/Triangular_4.is_tens_RawData
# 34  3DPrint/Triangular_4.is_tens_RawData
# 35  3DPrint/Triangular_6.is_tens_RawData
#
#                                   group2  meandiff   p-adj   lower   upper  \
# 0       3DPrint/Gyroid_6.is_tens_RawData    0.4523  0.0102  0.0753  0.8294
# 1       3DPrint/Gyroid_8.is_tens_RawData   -0.0200  1.0000 -0.3971  0.3570
# 2        3DPrint/Solid_4.is_tens_RawData    1.4803  0.0000  1.1032  1.8573
# 3        3DPrint/Solid_6.is_tens_RawData    1.4349  0.0000  1.0579  1.8120
# 4        3DPrint/Solid_8.is_tens_RawData    1.4698  0.0000  1.0927  1.8468
# 5   3DPrint/Triangular_4.is_tens_RawData   -0.7056  0.0000 -1.0826 -0.3286
# 6   3DPrint/Triangular_6.is_tens_RawData   -0.4218  0.0198 -0.7989 -0.0448
# 7   3DPrint/Triangular_8.is_tens_RawData   -0.2107  0.6321 -0.5877  0.1664
# 8       3DPrint/Gyroid_8.is_tens_RawData   -0.4723  0.0066 -0.8494 -0.0953
# 9        3DPrint/Solid_4.is_tens_RawData    1.0279  0.0000  0.6509  1.4050
# 10       3DPrint/Solid_6.is_tens_RawData    0.9826  0.0000  0.6056  1.3597
# 11       3DPrint/Solid_8.is_tens_RawData    1.0174  0.0000  0.6404  1.3945
# 12  3DPrint/Triangular_4.is_tens_RawData   -1.1579  0.0000 -1.5350 -0.7809
# 13  3DPrint/Triangular_6.is_tens_RawData   -0.8741  0.0000 -1.2512 -0.4971
# 14  3DPrint/Triangular_8.is_tens_RawData   -0.6630  0.0001 -1.0400 -0.2859
# 15       3DPrint/Solid_4.is_tens_RawData    1.5003  0.0000  1.1232  1.8773
# 16       3DPrint/Solid_6.is_tens_RawData    1.4550  0.0000  1.0779  1.8320
# 17       3DPrint/Solid_8.is_tens_RawData    1.4898  0.0000  1.1128  1.8668
# 18  3DPrint/Triangular_4.is_tens_RawData   -0.6856  0.0000 -1.0626 -0.3085
# 19  3DPrint/Triangular_6.is_tens_RawData   -0.4018  0.0302 -0.7788 -0.0248
# 20  3DPrint/Triangular_8.is_tens_RawData   -0.1906  0.7407 -0.5677  0.1864
# 21       3DPrint/Solid_6.is_tens_RawData   -0.0453  1.0000 -0.4224  0.3317
# 22       3DPrint/Solid_8.is_tens_RawData   -0.0105  1.0000 -0.3875  0.3666
# 23  3DPrint/Triangular_4.is_tens_RawData   -2.1859  0.0000 -2.5629 -1.8088
# 24  3DPrint/Triangular_6.is_tens_RawData   -1.9021  0.0000 -2.2791 -1.5250
# 25  3DPrint/Triangular_8.is_tens_RawData   -1.6909  0.0000 -2.0680 -1.3139
# 26       3DPrint/Solid_8.is_tens_RawData    0.0348  1.0000 -0.3422  0.4119
# 27  3DPrint/Triangular_4.is_tens_RawData   -2.1405  0.0000 -2.5176 -1.7635
# 28  3DPrint/Triangular_6.is_tens_RawData   -1.8568  0.0000 -2.2338 -1.4797
# 29  3DPrint/Triangular_8.is_tens_RawData   -1.6456  0.0000 -2.0226 -1.2685
# 30  3DPrint/Triangular_4.is_tens_RawData   -2.1754  0.0000 -2.5524 -1.7983
# 31  3DPrint/Triangular_6.is_tens_RawData   -1.8916  0.0000 -2.2686 -1.5145
# 32  3DPrint/Triangular_8.is_tens_RawData   -1.6804  0.0000 -2.0575 -1.3034
# 33  3DPrint/Triangular_6.is_tens_RawData    0.2838  0.2610 -0.0933  0.6608
# 34  3DPrint/Triangular_8.is_tens_RawData    0.4949  0.0039  0.1179  0.8720
# 35  3DPrint/Triangular_8.is_tens_RawData    0.2112  0.6293 -0.1659  0.5882
#
#     reject
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20   False
# 21   False
# 22   False
# 23    True
# 24    True
# 25    True
# 26   False
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33   False
# 34    True
# 35   False

# %% [markdown]
# #GOAL 1
